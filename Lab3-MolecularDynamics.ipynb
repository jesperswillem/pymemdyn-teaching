# %%
#!/usr/bin/env python3.7
import argparse
import os
import shutil
import sys

# Add PyMemDyn modules
sys.path.insert(0, '../')

import complex
import gromacs
import membrane
import protein
import pymemqueue
import settings
from pymemdyn import Run

# %%
# First, we intantiate the run class of pymemdyn, this top level object takes run time variables
# and stores them in an object so we can use them in the next steps
run = Run(own_dir = os.getcwd() + '/rundir',
          repo_dir = settings.TEMPLATES_DIR,
          pdb = 'protein.pdb',
          ligand = 'E3R',
          alosteric = None,
          waters = None,
          ions = None,
          cho = None,
          ligpargen = 'l',
          library = None,
          restraint = 'bw',
          queue = "",
          debug = False
)

# %%
run.moldyn()
# Out:
# Init
# LigandInit Step (1/35): pdb2gmx.
# LigandInit Step (2/35): set_itp.
# LigandInit Step (3/35): concat.
# LigandInit Step (4/35): editconf.
# LigandInit Step (5/35): set_protein_size.
# LigandInit Step (6/35): editconf2.
# LigandInit Step (7/35): set_protein_size2.
# LigandInit Step (8/35): set_popc.
# LigandInit Step (9/35): editconf3.
# LigandInit Step (10/35): make_ndx_lig.
# LigandInit Step (11/35): genrestr_lig.
# LigandInit Step (12/35): editconf4.
# LigandInit Step (13/35): make_topol.
# LigandInit Step (14/35): editconf5.
# LigandInit Step (15/35): solvate.
# LigandInit Step (16/35): set_water.
# LigandInit Step (17/35): editconf6.
# LigandInit Step (18/35): editconf7.
# LigandInit Step (19/35): solvate2.
# LigandInit Step (20/35): count_lipids.
# LigandInit Step (21/35): make_topol2.
# LigandInit Step (22/35): make_topol_lipids.
# LigandInit Step (23/35): make_ffoplsaanb.
# LigandInit Step (24/35): set_grompp.
# LigandInit Step (25/35): set_chains.
# LigandInit Step (26/35): make_ndx.
# Going to read 0 old index file(s)
# Analysing residue names:
# There are:   299    Protein residues
# There are:   164      Other residues
# There are: 11363      Water residues
# Analysing Protein...
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
#
#   0 System              : 47381 atoms
#   1 Protein             :  4758 atoms
#   2 Protein-H           :  2327 atoms
#   3 C-alpha             :   299 atoms
#   4 Backbone            :   897 atoms
#   5 MainChain           :  1197 atoms
#   6 MainChain+Cb        :  1480 atoms
#   7 MainChain+H         :  1485 atoms
#   8 SideChain           :  3273 atoms
#   9 SideChain-H         :  1130 atoms
#  10 Prot-Masses         :  4758 atoms
#  11 non-Protein         : 42623 atoms
#  12 Other               :  8534 atoms
#  13 LIG                 :    58 atoms
#  14 POP                 :  8476 atoms
#  15 Water               : 34089 atoms
#  16 SOL                 : 34089 atoms
#  17 non-Water           : 13292 atoms
#
#  nr : group      '!': not  'name' nr name   'splitch' nr    Enter: list groups
#  'a': atom       '&': and  'del' nr         'splitres' nr   'l': list residues
#  't': atom type  '|': or   'keep' nr        'splitat' nr    'h': help
#  'r': residue              'res' nr         'chain' char
#  "name": group             'case': case sensitive           'q': save and quit
#  'ri': residue index
#
# >
#
# LigandInit Step (27/35): grompp.
# LigandInit Step (28/35): trjconv.
# LigandInit Step (29/35): get_charge.
# LigandInit Step (30/35): genion.
# LigandInit Step (31/35): grompp2.
# LigandInit Step (32/35): trjconv2.
# LigandInit Step (33/35): grompp3.
# LigandInit Step (34/35): trjconv3.
# LigandInit Step (35/35): clean_pdb.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 run.moldyn()
#
# File ~/pymemdyn-teaching/notebook/../pymemdyn.py:156, in Run.moldyn(self)
#     154 print(step)
#     155 self.g.select_recipe(stage=step, debug=self.debug)
# --> 156 self.g.run_recipe(debug=self.debug)
#
# File ~/pymemdyn-teaching/notebook/../gromacs.py:319, in Gromacs.run_recipe(self, debug)
#     316     f = getattr(utils, command["command"])
#     318 if ("options") in command:
# --> 319     f(**command["options"])
#     320 else:
#     321     f()
#
# File ~/pymemdyn-teaching/notebook/../utils.py:12, in clean_pdb(src, tgt)
#       8 def clean_pdb(src = [], tgt = []):
#       9     """
#      10     Remove incorrectly allocated atom identifiers in pdb file
#      11     """
# ---> 12     source = open(src, "r")
#      13     lines_src = source.readlines()
#      14     source.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'hexagon.pdb'

# %%
!~/miniconda3/envs/pymemdyn/bin/gmx
# Out:
#                          :-) GROMACS - gmx, 2018.6 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar    Aldert van Buuren   Rudi van Drunen     Anton Feenstra
#   Gerrit Groenhof    Aleksei Iupinov   Christoph Junghans   Anca Hamuraru
#  Vincent Hindriksen Dimitrios Karkoulis    Peter Kasson        Jiri Kraus
#   Carsten Kutzner      Per Larsson      Justin A. Lemkul    Viveca Lindahl
#   Magnus Lundborg   Pieter Meulenhoff    Erik Marklund      Teemu Murtola
#     Szilard Pall       Sander Pronk      Roland Schulz     Alexey Shvetsov
#    Michael Shirts     Alfons Sijbers     Peter Tieleman    Teemu Virolainen
#  Christian Wennberg    Maarten Wolf
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2017, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx, version 2018.6
# Executable:   /home/willem/miniconda3/envs/pymemdyn/bin/gmx
# Data prefix:  /home/willem/miniconda3/envs/pymemdyn
# Working dir:  /home/willem/pymemdyn-teaching/notebook
# Command line:
#   gmx
#
# SYNOPSIS
#
# gmx [-[no]h] [-[no]quiet] [-[no]version] [-[no]copyright] [-nice <int>]
#     [-[no]backup]
#
# OPTIONS
#
# Other options:
#
#  -[no]h                     (no)
#            Print help and quit
#  -[no]quiet                 (no)
#            Do not print common startup info or quotes
#  -[no]version               (no)
#            Print extended version information and quit
#  -[no]copyright             (yes)
#            Print copyright information on startup
#  -nice   <int>              (19)
#            Set the nicelevel (default depends on command)
#  -[no]backup                (yes)
#            Write backups if output files exist
#
# Additional help is available on the following topics:
#     commands    List of available commands
#     selections  Selection syntax and usage
# To access the help, use 'gmx help <topic>'.
# For help on a command, use 'gmx help <command>'.
#
# GROMACS reminds you: "If You Touch Me, You'll Get Shocked" (Beastie Boys)
